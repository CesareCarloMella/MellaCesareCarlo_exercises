# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 5</span>

# %% [markdown]
# In quantum physics a **wave function**, $\Psi$, is a mathematical description of the state of a quantum system. The wave function is a complex-valued probability amplitude, and the probabilities for the possible results of measurements made on the system can be derived from it.
#
# For now on, let's consider the simple case of a non-relativistic single particle, without spin, in three spatial dimensions. The state of such a particle is completely described by its wave function, $\Psi(\vec{r},t)$, where $\vec{r}$ is position and $t$ is time.
#
# For one spinless particle, if the wave function is interpreted as a probability amplitude, the square modulus of the wave function, $|\Psi(\vec{r},t)|^2$, is interpreted as the probability density that the particle is at $\vec{r}$ at time $t$. Once we have a probability density, we can use Monte Carlo ...
#
# #### Hydrogen atom
# The wave functions of the eigenstates of an electron in a Hydrogen atom (this is the only atom for which the Schroedinger equation has been solved exactly) are expressed in terms of spherical harmonics and generalized Laguerre polynomials. It is convenient to use spherical coordinates, and the wave function can be separated into functions of each coordinate:
#
# $$
# \Psi_{n,l,m}(r,\theta,\phi)=
# \sqrt{\left(\frac{2}{na_0}\right)^3 \frac{(n-l-1)!}{2n[(n+l)!]}}
# e^{-r/na_0}\left(\frac{2r}{na_0}\right)^l L_{n-l-1}^{2l+1}\left(\frac{2r}{na_0}\right)
# Y_l^m(\theta,\phi)
# $$
#
# where $a_0=4\pi\epsilon_0\hbar^2/m_e e^2=0.0529$ nm is the Bohr radius, $L_{n-l-1}^{2l+1}$ are the generalized Laguerre polynomials of degree $n-l-1$, $n=1,2,...$ is the principal quantum number, $l=0,1, ..., n-1$ the azimuthal quantum number, $m=-l, -l+1, ..., l-1, l$ the magnetic quantum number.
#
# For example, the ground state wave function is:
# $$
# \Psi_{1,0,0}(r,\theta,\phi)=
# \frac{a_0^{-3/2}}{\sqrt{\pi}} e^{-r/a_0}
# $$
# whereas one of the three $2p$ excited state is:
# $$
# \Psi_{2,1,0}(r,\theta,\phi)=
# \frac{a_0^{-5/2}}{8}\sqrt{\frac{2}{\pi}} r e^{-r/2a_0} \cos(\theta)
# $$
# <span style="color:blue">Expectation values for the radius turns out to be exactly:
# $$
# \left\langle r \right\rangle_{\Psi_{1,0,0}} = \frac{3}{2}a_0
# \quad
# \left\langle r \right\rangle_{\Psi_{2,1,0}} = 5 a_0
# $$
# </span>
#
#
#
#
#
# I Used the Metropolis algorithm to sample $|\Psi_{1,0,0}(x,y,z)|^2$ and $|\Psi_{2,1,0}(x,y,z)|^2$ **in Cartesian coordinates** using an uniform transition probability $T(\vec{x}|\vec{y})$. I Used the sampled positions to estimate $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ and $\left\langle r \right\rangle_{\Psi_{2,1,0}}$.
#
# It is simpler to use $a_0$ as lenght unit.
# Explicitly, the two probability density above, in Cartesian coordinate, are:
#
# $$ |\Psi_{1,0,0}(x,y,z)|^2=\frac{1}{\pi}e^{-2\sqrt{x^2+y^2+z^2}} $$
#
# $$ |\Psi_{2,1,0}(x,y,z)|^2=\frac{z^2}{32\pi}e^{-\sqrt{x^2+y^2+z^2}} $$

# %% [markdown]
# ### <span style="color:blue"> Ground State     n=1, l=0, m=0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

read=open("RisultatiNotebook/risultati100/Parameters.dat")
x0=read.readline()
y0=read.readline()
z0=read.readline()
delta=read.readline()
M=read.readline()
N=read.readline()
read.close()
L=int(M)/int(N)
print("Simulazione eseguita estraendo M punti, con M =", M)
print("Statistica eseguita dividendo gli M punti in N blocchi, N =", N)
print("Initial position: \n")
print("x_0 =", x0)
print("y_0 =", y0)
print("z_0 =", z0)
fig = plt.figure(figsize=(10,8))
x,f,error=np.loadtxt("RisultatiNotebook/risultati100/progressivi100.out", usecols=(0,1,2), delimiter='   ', unpack='true')
x*=L
plt.errorbar(x,f,yerr=error)
plt.title("Mean radius as a function of the number of blocks")
plt.xlabel("#throws")
plt.ylabel("<r>")
plt.axhline(y=1.5, color='r')
plt.grid(True)
fig=plt.figure(figsize=(10,8))
n,x,y,z=np.loadtxt("RisultatiNotebook/risultati100/posizioni100.out", usecols=(0,1,2,3), delimiter='   ', unpack='true')
ax = Axes3D(fig)
ax.scatter(x, y, z, c=z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("First 10000 points")
ax.view_init(10, 30)
plt.show()
# Out:
# Simulazione eseguita estraendo M punti, con M = 1000000
#
# Statistica eseguita dividendo gli M punti in N blocchi, N = 100
#
# Initial position:
#
# x_0 = 1.5
#
# y_0 = 1.5
#
# z_0 = 1.5

# %% [markdown]
# ### <span style="color:blue"> Excited State     n=2, l=1, m=0

# %%
read=open("RisultatiNotebook/risultati210/Parameters.dat")
x0=read.readline()
y0=read.readline()
z0=read.readline()
delta=read.readline()
M=read.readline()
N=read.readline()
read.close()
L=int(M)/int(N)
print("Simulazione eseguita estraendo M punti, con M =", M)
print("Statistica eseguita dividendo gli M punti in N blocchi, N =", N)
print("Initial position: \n")
print("x_0 =", x0)
print("y_0 =", y0)
print("z_0 =", z0)
fig = plt.figure(figsize=(10,8))
x,f,error=np.loadtxt("RisultatiNotebook/risultati210/progressivi210.out", usecols=(0,1,2), delimiter='   ', unpack='true')
x*=L
plt.errorbar(x,f,yerr=error)
plt.title("Mean radius as a function of the number of blocks")
plt.xlabel("#throws")
plt.ylabel("<r>")
plt.axhline(y=5, color='r')
plt.grid(True)
fig=plt.figure(figsize=(10,8))
n,x,y,z=np.loadtxt("RisultatiNotebook/risultati210/posizioni210.out", usecols=(0,1,2,3), delimiter='   ', unpack='true')
ax = Axes3D(fig)
ax.scatter(x, y, z, c=z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("First 15000 points")
ax.view_init(10, 30)
plt.show()
# Out:
# Simulazione eseguita estraendo M punti, con M = 1000000
#
# Statistica eseguita dividendo gli M punti in N blocchi, N = 100
#
# Initial position:
#
# x_0 = 4.5
#
# y_0 = 4.5
#
# z_0 = 4.5

# %% [markdown]
# ### Testing initial condition
# I tried to change my initial choices for the ground state sampling.
# I set equal to 20 the three coordinates.
# The algorithm works as before, but now it is evident that it need more time to converge. From the first plot we can see the convergence speed in computing the mean radius, while in the second plot it is clear that a specific trend guides the sampling for the initial points.

# %%
read=open("RisultatiNotebook/Sbagliando/risultati100/Parameters.dat")
x0=read.readline()
y0=read.readline()
z0=read.readline()
delta=read.readline()
M=read.readline()
N=read.readline()
read.close()
L=int(M)/int(N)
print("Simulazione eseguita estraendo M punti, con M =", M)
print("Statistica eseguita dividendo gli M punti in N blocchi, N =", N)
print("Initial position: \n")
print("x_0 =", x0)
print("y_0 =", y0)
print("z_0 =", z0)
fig = plt.figure(figsize=(10,8))
x,f,error=np.loadtxt("RisultatiNotebook/Sbagliando/risultati100/progressivi100.out", usecols=(0,1,2), delimiter='   ', unpack='true')
x*=L
plt.errorbar(x,f,yerr=error)
plt.title("Mean radius as a function of the number of blocks")
plt.xlabel("#throws")
plt.ylabel("<r>")
plt.axhline(y=1.5, color='r')
plt.grid(True)
fig=plt.figure(figsize=(10,8))
n,x,y,z=np.loadtxt("RisultatiNotebook/Sbagliando/risultati100/posizioni100.out", usecols=(0,1,2,3), delimiter='   ', unpack='true')
ax = Axes3D(fig)
ax.scatter(x, y, z, c=z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("First 10000 points")
ax.view_init(10, 30)
plt.show()
# Out:
# Simulazione eseguita estraendo M punti, con M = 1000000
#
# Statistica eseguita dividendo gli M punti in N blocchi, N = 100
#
# Initial position:
#
# x_0 = 20
#
# y_0 = 20
#
# z_0 = 20

# %% [markdown]
# ### Gaussian T_sampling
#
# I tried to sample gaussian points. Statistically, I can't point out significant differences.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

read=open("RisultatiNotebook/risultatiGauss/Parameters.dat")
x0=read.readline()
y0=read.readline()
z0=read.readline()
delta=read.readline()
M=read.readline()
N=read.readline()
read.close()
L=int(M)/int(N)
print("Simulazione eseguita estraendo M punti, con M =", M)
print("Statistica eseguita dividendo gli M punti in N blocchi, N =", N)
print("Initial position: \n")
print("x_0 =", x0)
print("y_0 =", y0)
print("z_0 =", z0)
fig = plt.figure(figsize=(10,8))
x,f,error=np.loadtxt("RisultatiNotebook/risultatiGauss/progressivi100.out", usecols=(0,1,2), delimiter='   ', unpack='true')
x*=L
plt.errorbar(x,f,yerr=error)
plt.title("Mean radius as a function of the number of blocks")
plt.xlabel("#throws")
plt.ylabel("<r>")
plt.axhline(y=1.5, color='r')
plt.grid(True)
fig=plt.figure(figsize=(10,8))
n,x,y,z=np.loadtxt("RisultatiNotebook/risultatiGauss/posizioni100.out", usecols=(0,1,2,3), delimiter='   ', unpack='true')
ax = Axes3D(fig)
ax.scatter(x, y, z, c=z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("First 10000 points")
ax.view_init(10, 30)
plt.show()
# Out:
# Simulazione eseguita estraendo M punti, con M = 1000000
#
# Statistica eseguita dividendo gli M punti in N blocchi, N = 100
#
# Initial position:
#
# x_0 = 1.5
#
# y_0 = 1.5
#
# z_0 = 1.5
