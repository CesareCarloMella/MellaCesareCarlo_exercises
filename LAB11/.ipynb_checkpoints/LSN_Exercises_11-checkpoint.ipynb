# Epoch 19/30
# 100/100 [==============================] - ETA: 0s - loss: 0.3457 - mean_squared_error: 0.34 - 0s 123us/step - loss: 0.3075 - mean_squared_error: 0.3075 - val_loss: 0.3488 - val_mean_squared_error: 0.3488
# Epoch 20/30
# 100/100 [==============================] - 0s 168us/step - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.3209 - val_mean_squared_error: 0.3209
# Epoch 21/30
# 100/100 [==============================] - 0s 118us/step - loss: 0.2656 - mean_squared_error: 0.2656 - val_loss: 0.2982 - val_mean_squared_error: 0.2982
# Epoch 22/30
# 100/100 [==============================] - 0s 114us/step - loss: 0.2497 - mean_squared_error: 0.2497 - val_loss: 0.2752 - val_mean_squared_error: 0.2752
# Epoch 23/30
# 100/100 [==============================] - 0s 122us/step - loss: 0.2330 - mean_squared_error: 0.2330 - val_loss: 0.2568 - val_mean_squared_error: 0.2568
# Epoch 24/30
# 100/100 [==============================] - 0s 125us/step - loss: 0.2194 - mean_squared_error: 0.2194 - val_loss: 0.2361 - val_mean_squared_error: 0.2361
# Epoch 25/30
# 100/100 [==============================] - 0s 111us/step - loss: 0.2049 - mean_squared_error: 0.2049 - val_loss: 0.2151 - val_mean_squared_error: 0.2151
# Epoch 26/30
# 100/100 [==============================] - 0s 125us/step - loss: 0.1903 - mean_squared_error: 0.1903 - val_loss: 0.2026 - val_mean_squared_error: 0.2026
# Epoch 27/30
# 100/100 [==============================] - 0s 121us/step - loss: 0.1798 - mean_squared_error: 0.1798 - val_loss: 0.1900 - val_mean_squared_error: 0.1900
# Epoch 28/30
# 100/100 [==============================] - 0s 126us/step - loss: 0.1700 - mean_squared_error: 0.1700 - val_loss: 0.1775 - val_mean_squared_error: 0.1775
# Epoch 29/30
# 100/100 [==============================] - 0s 121us/step - loss: 0.1608 - mean_squared_error: 0.1608 - val_loss: 0.1653 - val_mean_squared_error: 0.1653
# Epoch 30/30
# 100/100 [==============================] - 0s 114us/step - loss: 0.1515 - mean_squared_error: 0.1515 - val_loss: 0.1566 - val_mean_squared_error: 0.1566

# %%
# return weights
model.get_weights()
# Out:
# [array([[1.3495662]], dtype=float32), array([0.89027065], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test mean square error:', score[1])
# Out:
# 10/10 [==============================] - 0s 209us/step
#
# Test loss: 0.1566305160522461
# Test mean square error: 0.1566305160522461

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test mean square error:', score[1])
# Out:
# 10/10 [==============================] - 0s 162us/step
#
# Test loss: 0.1566305160522461
# Test mean square error: 0.1566305160522461

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %%
# generate training inputs
np.random.seed(0)
#100 dati di training e 10 dati di validation
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 100)
#ordina i dati di validation
x_valid.sort()
#funzione esatta
y_target = m * x_valid + b # ideal (target) linear function

sigma = 1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')

plt.grid(True); plt.show()

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=10,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/10
# 1000/1000 [==============================] - 0s 73us/step - loss: 1.0766 - mean_squared_error: 1.0766 - val_loss: 1.0189 - val_mean_squared_error: 1.0189
# Epoch 2/10
# 1000/1000 [==============================] - 0s 81us/step - loss: 1.0283 - mean_squared_error: 1.0283 - val_loss: 0.9625 - val_mean_squared_error: 0.9625
# Epoch 3/10
# 1000/1000 [==============================] - 0s 76us/step - loss: 0.9995 - mean_squared_error: 0.9995 - val_loss: 0.9215 - val_mean_squared_error: 0.9215
# Epoch 4/10
# 1000/1000 [==============================] - 0s 74us/step - loss: 0.9808 - mean_squared_error: 0.9808 - val_loss: 0.8954 - val_mean_squared_error: 0.8954
# Epoch 5/10
# 1000/1000 [==============================] - 0s 79us/step - loss: 0.9698 - mean_squared_error: 0.9698 - val_loss: 0.8767 - val_mean_squared_error: 0.8767
# Epoch 6/10
# 1000/1000 [==============================] - 0s 72us/step - loss: 0.9624 - mean_squared_error: 0.9624 - val_loss: 0.8635 - val_mean_squared_error: 0.8635
# Epoch 7/10
# 1000/1000 [==============================] - 0s 73us/step - loss: 0.9578 - mean_squared_error: 0.9578 - val_loss: 0.8533 - val_mean_squared_error: 0.8533
# Epoch 8/10
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.9545 - mean_squared_error: 0.9545 - val_loss: 0.8453 - val_mean_squared_error: 0.8453
# Epoch 9/10
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.9520 - mean_squared_error: 0.9520 - val_loss: 0.8391 - val_mean_squared_error: 0.8391
# Epoch 10/10
# 1000/1000 [==============================] - 0s 80us/step - loss: 0.9508 - mean_squared_error: 0.9508 - val_loss: 0.8347 - val_mean_squared_error: 0.8347

# %%
# return weights
model.get_weights()
# Out:
# [array([[1.9341984]], dtype=float32), array([1.0291506], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 100/100 [==============================] - 0s 61us/step
#
# Test loss: 0.8346596479415893
# Test accuracy: 0.8346596479415893

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 100/100 [==============================] - 0s 66us/step
#
# Test loss: 0.0026791775692254303
# Test accuracy: 0.0026791775692254303

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# Also with a big noise ( $\sigma = 1.0$ ) the NN works well. I think it is due to the fact that the model is too simple and it is able to fit well straight line, that is what we have! If we didn't know the result we could think that the model is too simple, looking to the loss. For a more complicated model with the same noise I expect an overfitting of the data.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# In order to make practice with NN, explore reasonable different choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Make graphs comparing fits for different NNs.
# Check your NN models by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
a=4
b=-3
c=-2
d=3


def f(x,a,b,c,d):
    return a+b*x+c*x*x+d*x*x*x

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
#100 dati di training e 10 dati di validation
x_train = np.random.uniform(-1, 1.5, 1000)
x_valid = np.random.uniform(-1, 1.5, 100)
#ordina i dati di validation
x_valid.sort()
#funzione esatta
y_target = f(x_valid,a,b,c,d) # ideal (target) linear function

sigma = 1.5 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(f(x_train,a,b,c,d), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid,a,b,c,d), sigma)

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')

plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))
model.add(Dense(100,activation='tanh'))
model.add(Dense(100,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               200
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 30,603
# Trainable params: 30,603
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/100
# 1000/1000 [==============================] - 2s 2ms/step - loss: 5.9657 - mean_squared_error: 5.9657 - val_loss: 2.7635 - val_mean_squared_error: 2.7635
# Epoch 2/100
# 1000/1000 [==============================] - 1s 558us/step - loss: 3.0160 - mean_squared_error: 3.0160 - val_loss: 2.7353 - val_mean_squared_error: 2.7353
# Epoch 3/100
# 1000/1000 [==============================] - 1s 606us/step - loss: 2.8956 - mean_squared_error: 2.8956 - val_loss: 3.2437 - val_mean_squared_error: 3.2437
# 1000/1000 [==============================] - 1s 681us/step - loss: 2.1911 - mean_squared_error: 2.1911 - val_loss: 1.8677 - val_mean_squared_error: 1.8677
# Epoch 93/100
# 1000/1000 [==============================] - 0s 452us/step - loss: 2.1717 - mean_squared_error: 2.1717 - val_loss: 3.0730 - val_mean_squared_error: 3.0730
# Epoch 94/100
# 1000/1000 [==============================] - 0s 349us/step - loss: 2.2587 - mean_squared_error: 2.2587 - val_loss: 1.8976 - val_mean_squared_error: 1.8976
# Epoch 95/100
# 1000/1000 [==============================] - 0s 425us/step - loss: 2.1516 - mean_squared_error: 2.1516 - val_loss: 2.1050 - val_mean_squared_error: 2.1050
# Epoch 96/100
# 1000/1000 [==============================] - 0s 393us/step - loss: 2.2080 - mean_squared_error: 2.2080 - val_loss: 1.8627 - val_mean_squared_error: 1.8627
# Epoch 97/100
# 1000/1000 [==============================] - 1s 547us/step - loss: 2.1849 - mean_squared_error: 2.1849 - val_loss: 2.0672 - val_mean_squared_error: 2.0672
# Epoch 98/100
# 1000/1000 [==============================] - 0s 396us/step - loss: 2.2190 - mean_squared_error: 2.2190 - val_loss: 2.0215 - val_mean_squared_error: 2.0215
# Epoch 99/100
# 1000/1000 [==============================] - 0s 370us/step - loss: 2.1747 - mean_squared_error: 2.1747 - val_loss: 1.8886 - val_mean_squared_error: 1.8886
# Epoch 100/100
# 1000/1000 [==============================] - 0s 485us/step - loss: 2.1914 - mean_squared_error: 2.1914 - val_loss: 1.9338 - val_mean_squared_error: 1.9338

# %%
#model.get_weights()

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test mean square value:', score[1])
# Out:
# 100/100 [==============================] - 0s 328us/step
#
# Test loss: 1.9337934017181397
# Test mean square value: 1.9337934017181397

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test mean square value:', score[1])
# Out:
# 100/100 [==============================] - 0s 225us/step
#
# Test loss: 0.0937357085943222
# Test mean square value: 0.0937357085943222

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
x_predicted.sort()
y_target = f(x_predicted,a,b,c,d) # ideal (target) linear function
plt.plot(x_predicted,y_target)

plt.grid(True)
plt.show()

# %% [markdown]
# This exercise shows the importance of having a sufficiently complicated model. With two layers the fit is complitely wrong. Adding one or two more layer with 20 n. things are different, but still not acceptable.
# Finally, if we add another layer the model starts to works very well.
# In the final configuration I added a noise $\sigma = 0.7 $. Altough the data are quite terrible it seems to find the rigth shape, with a little shift. Now, raising the number of epochs to 100, the fit returns to be very acceptable!
# Finally, I searched for the overfitting threshold. I've given up! the model continues to works well also with a very big noise ($ \sigma=1.7$) and a very complicated sequence of layer.

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def f(x,y):
    return np.sin(x**2.+y**2.)

# %%
x=np.linspace(-1.5,1.5,100)
y=np.linspace(-1.5,1.5,100)

ax = Axes3D(fig=plt.figure(figsize=(7,7)))
x,y=np.meshgrid(x,y)
z=f(x,y)
ax.plot_surface(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("Function")
ax.view_init(30, 30)
plt.show()

# %%
# generate training inputs
np.random.seed(0)
#100 dati di training e 10 dati di validation
n_train=5000
n_valid=500
sigma=0.1

x_train=np.zeros((n_train, 2))
y_train=np.zeros((n_train,1))
for i in range(n_train):
    x_train[i][0]=np.random.uniform(-1.5,1.5)
    x_train[i][1]=np.random.uniform(-1.5,1.5)
    y_train[i]=np.random.normal(f(x_train[i][0],x_train[i][1]),sigma)


x_valid = np.zeros((n_valid,2))
y_valid = np.zeros((n_valid,1))
Xplot=np.zeros((n_valid,1))
Yplot=np.zeros((n_valid,1))
for i in range(n_valid):
    x_valid[i][0]=np.random.uniform(-1.5,1.5)
    x_valid[i][1]=np.random.uniform(-1.5,1.5)
    Xplot[i]=x_valid[i][0]
    Yplot[i]=x_valid[i][1]
    y_valid[i]=np.random.normal(f(x_valid[i][0],x_valid[i][1]),sigma)
    #Quello esatto

# %%
# plot training and target dataset
ax = Axes3D(fig=plt.figure(figsize=(7,7)))

ax.scatter(Xplot,Yplot,y_valid, color='r')
z=f(x,y)
ax.plot_surface(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("Validation Data")
ax.view_init(30, 30)

plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(2, input_shape=(2,)))
model.add(Dense(30,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                90
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_10 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 1,987
# Trainable params: 1,987
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
X_TRAIN=(x_train,y_train)
X_VALID=(x_valid,y_valid)
history = model.fit(x=x_train,y=y_train ,
          batch_size=32, epochs=100,       
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 5000 samples, validate on 500 samples
# Epoch 1/100
# 5000/5000 [==============================] - 4s 781us/step - loss: 0.1948 - mean_squared_error: 0.1948 - val_loss: 0.1486 - val_mean_squared_error: 0.1486
# Epoch 2/100
# 5000/5000 [==============================] - 2s 468us/step - loss: 0.1496 - mean_squared_error: 0.1496 - val_loss: 0.1453 - val_mean_squared_error: 0.1453
# Epoch 3/100
# 5000/5000 [==============================] - 3s 502us/step - loss: 0.1461 - mean_squared_error: 0.1461 - val_loss: 0.1414 - val_mean_squared_error: 0.1414
# Epoch 4/100
# 5000/5000 [==============================] - 2s 394us/step - loss: 0.1426 - mean_squared_error: 0.1426 - val_loss: 0.1396 - val_mean_squared_error: 0.1396
# Epoch 5/100
# 5000/5000 [==============================] - 2s 364us/step - loss: 0.1393 - mean_squared_error: 0.1393 - val_loss: 0.1338 - val_mean_squared_error: 0.1338
# Epoch 6/100
# 5000/5000 [==============================] - 2s 444us/step - loss: 0.1356 - mean_squared_error: 0.1356 - val_loss: 0.1300 - val_mean_squared_error: 0.1300
# Epoch 7/100
# 5000/5000 [==============================] - 2s 459us/step - loss: 0.1311 - mean_squared_error: 0.1311 - val_loss: 0.1251 - val_mean_squared_error: 0.1251
# Epoch 8/100
# 5000/5000 [==============================] - 2s 385us/step - loss: 0.1273 - mean_squared_error: 0.1273 - val_loss: 0.1214 - val_mean_squared_error: 0.1214
# Epoch 9/100
# 5000/5000 [==============================] - 2s 436us/step - loss: 0.1236 - mean_squared_error: 0.1236 - val_loss: 0.1173 - val_mean_squared_error: 0.1173
# Epoch 10/100
# 5000/5000 [==============================] - 2s 493us/step - loss: 0.1195 - mean_squared_error: 0.1195 - val_loss: 0.1121 - val_mean_squared_error: 0.1121
# Epoch 11/100
# 5000/5000 [==============================] - 2s 422us/step - loss: 0.1154 - mean_squared_error: 0.1154 - val_loss: 0.1080 - val_mean_squared_error: 0.1080
step - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 31/100
# 5000/5000 [==============================] - 3s 544us/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 32/100
# 5000/5000 [==============================] - 3s 509us/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 33/100
# 5000/5000 [==============================] - 3s 609us/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 34/100
# 5000/5000 [==============================] - 3s 689us/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 35/100
# 5000/5000 [==============================] - 3s 637us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 36/100
# 5000/5000 [==============================] - 3s 540us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 37/100
# 5000/5000 [==============================] - 3s 663us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 38/100
# 5000/5000 [==============================] - 4s 708us/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 39/100
# 5000/5000 [==============================] - 3s 621us/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 40/100
# 5000/5000 [==============================] - 3s 539us/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 41/100
# 5000/5000 [==============================] - 3s 544us/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 42/100
# 5000/5000 [==============================] - 3s 616us/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 43/100
# 5000/5000 [==============================] - 3s 533us/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 44/100
# 5000/5000 [==============================] - 3s 600us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 45/100
# 5000/5000 [==============================] - 3s 600us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 46/100
# 5000/5000 [==============================] - 3s 553us/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 47/100
# 5000/5000 [==============================] - 3s 560us/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 48/100
# 5000/5000 [==============================] - 2s 450us/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 49/100
# 5000/5000 [==============================] - 2s 437us/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 50/100
# 5000/5000 [==============================] - 2s 498us/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 51/100
# 5000/5000 [==============================] - 2s 437us/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 52/100
# 5000/5000 [==============================] - 2s 400us/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 53/100
# 5000/5000 [==============================] - 2s 451us/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 54/100
# 5000/5000 [==============================] - 2s 411us/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 55/100
# 5000/5000 [==============================] - 2s 379us/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 56/100
# 5000/5000 [==============================] - 2s 421us/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 57/100
# 5000/5000 [==============================] - 3s 536us/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 58/100
# 5000/5000 [==============================] - 2s 421us/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 59/100
# 5000/5000 [==============================] - 2s 390us/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 60/100
# 5000/5000 [==============================] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.01 - 3s 674us/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 61/100
# 5000/5000 [==============================] - 3s 544us/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 62/100
# 5000/5000 [==============================] - 2s 449us/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 63/100
# 5000/5000 [==============================] - 3s 633us/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 64/100
# 5000/5000 [==============================] - 3s 622us/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 65/100
# 5000/5000 [==============================] - 3s 557us/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 66/100
# 5000/5000 [==============================] - 3s 537us/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 67/100
# 5000/5000 [==============================] - 4s 756us/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 68/100
# 5000/5000 [==============================] - 3s 695us/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 69/100
# 5000/5000 [==============================] - 3s 601us/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 70/100
# 5000/5000 [==============================] - 3s 506us/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 71/100
# 5000/5000 [==============================] - 2s 434us/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 72/100
# 5000/5000 [==============================] - 3s 520us/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 73/100
# 5000/5000 [==============================] - 4s 718us/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 74/100
# 5000/5000 [==============================] - 3s 601us/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 75/100
# 5000/5000 [==============================] - 3s 600us/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 76/100
# 5000/5000 [==============================] - 2s 434us/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 77/100
# 5000/5000 [==============================] - 3s 534us/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 78/100
# 5000/5000 [==============================] - 3s 675us/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 79/100
# 5000/5000 [==============================] - 3s 540us/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 80/100
# 5000/5000 [==============================] - 3s 660us/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 81/100
# 5000/5000 [==============================] - 4s 728us/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 82/100
# 5000/5000 [==============================] - 3s 613us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 83/100
# 5000/5000 [==============================] - 3s 580us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 84/100
# 5000/5000 [==============================] - 3s 529us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 85/100
# 5000/5000 [==============================] - 2s 483us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 86/100
# 5000/5000 [==============================] - 2s 492us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 87/100
# 5000/5000 [==============================] - 3s 501us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 88/100
# 5000/5000 [==============================] - 2s 468us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 89/100
# 5000/5000 [==============================] - 3s 574us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 90/100
# 5000/5000 [==============================] - 3s 663us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 91/100
# 5000/5000 [==============================] - 3s 535us/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 92/100
# 5000/5000 [==============================] - 3s 530us/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 93/100
# 5000/5000 [==============================] - 2s 447us/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 94/100
# 5000/5000 [==============================] - 2s 400us/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 95/100
# 5000/5000 [==============================] - 3s 506us/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 96/100
# 5000/5000 [==============================] - 3s 525us/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 97/100
# 5000/5000 [==============================] - 2s 386us/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 98/100
# 5000/5000 [==============================] - 2s 436us/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 99/100
# 5000/5000 [==============================] - 3s 560us/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 100/100
# 5000/5000 [==============================] - 3s 559us/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0124 - val_mean_squared_error: 0.0124

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test mean square value:', score[1])
# Out:
# 500/500 [==============================] - 0s 543us/step
#
# Test loss: 0.0123865020647645
# Test mean square value: 0.0123865020647645

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
ax = Axes3D(fig=plt.figure(figsize=(7,7)))


x_predicted=np.zeros((1000, 2))
Xplot=np.zeros((1000,1))
Yplot=np.zeros((1000,1))

for i in range(1000):
    x_predicted[i][0]=np.random.uniform(-1.5,1.5)
    Xplot[i]=x_predicted[i][0]
    x_predicted[i][1]=np.random.uniform(-1.5,1.5)
    Yplot[i]=x_predicted[i][1]
    
y_predicted = model.predict(x_predicted)


ax.scatter(Xplot, Yplot,y_predicted,color='r')
ax.plot_surface(x,y,z)
ax.view_init(30, 30)
plt.grid(True)
plt.show()

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>

# %% [markdown]
# ### <span style="color:green">Supplementary material: Keras model.fit available callbacks</span>

# %% [markdown]
# The .fit method can also get <a href=https://keras.io/callbacks/>callback</a> functions which can be used to customize the fitting procedure with special actions.
#
# Keras provides some predefined callbacks to feed in, among them for example:
# - **TerminateOnNaN()**: that terminates training when a NaN loss is encountered
# - **ModelCheckpoint(filepath)**: that save the model after every epoch
# - **EarlyStopping()**: which stop training when a monitored quantity has stopped improving
#
# You can select one or more callback and pass them as a list to the callback argument of the fit method.

# %% [markdown]
# Now we are going to construct a callback object to represent how estimated parameters are converging during the training procedure

# %%
from IPython.display import clear_output

class PlotCurrentEstimate(tf.keras.callbacks.Callback):
    def __init__(self, x_valid, y_valid):
        """Keras Callback which plot current model estimate against reference target"""
        
        # convert numpy arrays into lists for plotting purposes
        self.x_valid = list(x_valid[:])
        self.y_valid = list(y_valid[:])
        self.iter=0

    def on_epoch_end(self, epoch, logs={}):
        
        temp = self.model.predict(self.x_valid, batch_size=None, verbose=False, steps=None)
        self.y_curr = list(temp[:]) # convert numpy array into list
        
        self.iter+=1
        if self.iter%10 == 0:
            clear_output(wait=True)            
            self.eplot = plt.subplot(1,1,1)
            self.eplot.clear()     
            self.eplot.scatter(self.x_valid, self.y_curr, color="blue", s=4, marker="o", label="estimate")
            self.eplot.scatter(self.x_valid, self.y_valid, color="red", s=4, marker="x", label="valid")
            self.eplot.legend()

            plt.show()

# %% [markdown]
# We will use also an EarlyStopping callback on the val_loss quantity. This will stop the training process as soon as the val_loss quantity does not improve anymore after an amount of epochs, preventing a long time of wated computation to take over without useful results.
#
# <code>keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)</code>
#
# Arguments:
#
# - <code>monitor</code>: quantity to be monitored.
# - <code>min_delta:</code> minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
# - <code>patience:</code> number of epochs with no improvement after which training will be stopped.
# - <code>verbose:</code> verbosity mode.
# - <code>mode:</code> one of {auto, min, max}. In min mode, training will stop when the quantity monitored has stopped decreasing; in max mode it will stop when the quantity monitored has stopped increasing; in auto mode, the direction is automatically inferred from the name of the monitored quantity.
# - <code>baseline:</code> Baseline value for the monitored quantity to reach. Training will stop if the model doesn't show improvement over the baseline.
# - <code>restore_best_weights:</code> whether to restore model weights from the epoch with the best value of the monitored quantity. If False, the model weights obtained at the last step of training are used.

# %%
plot_estimate = PlotCurrentEstimate(x_valid, y_valid)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

model.fit(x_valid, y_valid, batch_size=32, epochs=150,
          validation_data=(x_valid, y_valid),
          callbacks=[ plot_estimate, earlystop]
          )

model.get_weights()
# Out:
# Train on 500 samples, validate on 500 samples
# Epoch 1/150
# 480/500 [===========================>..] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-9961ee82bc6a> in <module>()
#       6 model.fit(x_valid, y_valid, batch_size=32, epochs=150,
#       7           validation_data=(x_valid, y_valid),
# ----> 8           callbacks=[ plot_estimate, earlystop]
#       9           )
#      10
#
# ~/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1637           initial_epoch=initial_epoch,
#    1638           steps_per_epoch=steps_per_epoch,
# -> 1639           validation_steps=validation_steps)
#    1640
#    1641   def evaluate(self,
#
# ~/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_arrays.py in fit_loop(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps)
#     237             for l, o in zip(model.metrics_names, val_outs):
#     238               epoch_logs['val_' + l] = o
# --> 239     callbacks.on_epoch_end(epoch, epoch_logs)
#     240     if callbacks.model.stop_training:
#     241       break
#
# ~/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     212     logs = logs or {}
#     213     for callback in self.callbacks:
# --> 214       callback.on_epoch_end(epoch, logs)
#     215
#     216   def on_batch_begin(self, batch, logs=None):
#
# <ipython-input-41-996b743df9f3> in on_epoch_end(self, epoch, logs)
#      12     def on_epoch_end(self, epoch, logs={}):
#      13
# ---> 14         temp = self.model.predict(self.x_valid, batch_size=None, verbose=False, steps=None)
#      15         self.y_curr = list(temp[:]) # convert numpy array into list
#      16
#
# ~/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, max_queue_size, workers, use_multiprocessing)
#    1862     # means that we end up calculating it twice which we should avoid.
#    1863     x, _, _ = self._standardize_user_data(
# -> 1864         x, check_steps=True, steps_name='steps', steps=steps)
#    1865
#    1866     if context.executing_eagerly():
#
# ~/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split)
#     990         x, y, sample_weight = next_element
#     991     x, y, sample_weights = self._standardize_weights(x, y, sample_weight,
# --> 992                                                      class_weight, batch_size)
#     993     return x, y, sample_weights
#     994
#
# ~/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _standardize_weights(self, x, y, sample_weight, class_weight, batch_size)
#    1115         feed_input_shapes,
#    1116         check_batch_axis=False,  # Don't enforce the batch size.
# -> 1117         exception_prefix='input')
#    1118
#    1119     if y is not None:
#
# ~/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     291                        'Expected to see ' + str(len(names)) + ' array(s), '
#     292                        'but instead got the following list of ' +
# --> 293                        str(len(data)) + ' arrays: ' + str(data)[:200] + '...')
#     294     elif len(names) > 1:
#     295       raise ValueError(
#
# ValueError: Error when checking model input: the list of Numpy arrays that you are passing to your model is not the size the model expected. Expected to see 1 array(s), but instead got the following list of 500 arrays: [array([[1.41106944],
#        [0.58435965]]), array([[ 0.58557974],
#        [-0.72270293]]), array([[-0.58186509],
#        [ 0.46534417]]), array([[0.31703845],
#        [0.5107891 ]]), array([[-1.05126093...
